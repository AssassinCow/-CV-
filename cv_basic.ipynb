# %% [markdown]
# RGB:三个颜色通道

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline  

img=cv2.imread(r"D:\picture\p2.jpg")

# %%
img
# Out:
# array([[[ 51, 106, 149],
#         [ 53, 108, 151],
#         [ 52, 107, 150],
#         ...,
#         [ 98, 150, 190],
#         [ 98, 150, 190],
#         [ 97, 149, 189]],
#
#        [[ 50, 105, 148],
#         [ 51, 106, 149],
#         [ 51, 106, 149],
#         ...,
#         [ 99, 151, 191],
#         [ 98, 150, 190],
#         [ 96, 148, 188]],
#
#        [[ 51, 106, 149],
#         [ 51, 106, 149],
#         [ 52, 107, 150],
#         ...,
#         [100, 152, 192],
#         [ 99, 151, 191],
#         [ 96, 148, 188]],
#
#        ...,
#
#        [[119, 164, 202],
#         [120, 165, 203],
#         [119, 164, 202],
#         ...,
#         [ 54, 112, 161],
#         [ 55, 114, 163],
#         [ 56, 115, 164]],
#
#        [[116, 163, 201],
#         [118, 165, 203],
#         [117, 164, 202],
#         ...,
#         [ 50, 109, 159],
#         [ 51, 110, 160],
#         [ 55, 114, 164]],
#
#        [[115, 162, 200],
#         [117, 164, 202],
#         [116, 163, 201],
# ...

# %%
def cv_show(name,img):
    cv2.imshow(name,img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
cv_show('image',img)

# %%
img.shape
# Out:
# (1536, 1024, 3)

# %%
img=cv2.imread(r"D:\picture\p2.jpg",cv2.IMREAD_GRAYSCALE)
img
# Out:
# array([[113, 115, 114, ..., 156, 156, 155],
#        [112, 113, 113, ..., 157, 156, 154],
#        [113, 113, 114, ..., 158, 157, 154],
#        ...,
#        [170, 171, 170, ..., 120, 122, 123],
#        [169, 171, 170, ..., 117, 118, 122],
#        [168, 170, 169, ..., 114, 116, 121]],
#       shape=(1536, 1024), dtype=uint8)

# %%
img.shape
# Out:
# (1536, 1024)

# %%
cv_show('image',img)

# %%
img=cv2.imread(r"D:\picture\p2.jpg")
img
# Out:
# array([[[ 51, 106, 149],
#         [ 53, 108, 151],
#         [ 52, 107, 150],
#         ...,
#         [ 98, 150, 190],
#         [ 98, 150, 190],
#         [ 97, 149, 189]],
#
#        [[ 50, 105, 148],
#         [ 51, 106, 149],
#         [ 51, 106, 149],
#         ...,
#         [ 99, 151, 191],
#         [ 98, 150, 190],
#         [ 96, 148, 188]],
#
#        [[ 51, 106, 149],
#         [ 51, 106, 149],
#         [ 52, 107, 150],
#         ...,
#         [100, 152, 192],
#         [ 99, 151, 191],
#         [ 96, 148, 188]],
#
#        ...,
#
#        [[119, 164, 202],
#         [120, 165, 203],
#         [119, 164, 202],
#         ...,
#         [ 54, 112, 161],
#         [ 55, 114, 163],
#         [ 56, 115, 164]],
#
#        [[116, 163, 201],
#         [118, 165, 203],
#         [117, 164, 202],
#         ...,
#         [ 50, 109, 159],
#         [ 51, 110, 160],
#         [ 55, 114, 164]],
#
#        [[115, 162, 200],
#         [117, 164, 202],
#         [116, 163, 201],
# ...

# %%
cat=img[500:700,400:600]
cv_show('cat',cat)

# %%
b,g,r=cv2.split(img)

# %%
b,g,r
# Out:
# (array([[ 51,  53,  52, ...,  98,  98,  97],
#         [ 50,  51,  51, ...,  99,  98,  96],
#         [ 51,  51,  52, ..., 100,  99,  96],
#         ...,
#         [119, 120, 119, ...,  54,  55,  56],
#         [116, 118, 117, ...,  50,  51,  55],
#         [115, 117, 116, ...,  47,  49,  54]],
#        shape=(1536, 1024), dtype=uint8),
#  array([[106, 108, 107, ..., 150, 150, 149],
#         [105, 106, 106, ..., 151, 150, 148],
#         [106, 106, 107, ..., 152, 151, 148],
#         ...,
#         [164, 165, 164, ..., 112, 114, 115],
#         [163, 165, 164, ..., 109, 110, 114],
#         [162, 164, 163, ..., 106, 108, 113]],
#        shape=(1536, 1024), dtype=uint8),
#  array([[149, 151, 150, ..., 190, 190, 189],
#         [148, 149, 149, ..., 191, 190, 188],
#         [149, 149, 150, ..., 192, 191, 188],
#         ...,
#         [202, 203, 202, ..., 161, 163, 164],
#         [201, 203, 202, ..., 159, 160, 164],
#         [200, 202, 201, ..., 156, 158, 163]],
# ...

# %%
img=cv2.merge((b,g,r))
cv_show('bgr',img)

# %%
cur_img=img.copy()
cur_img[:,:,0]=0
cur_img[:,:,1]=0
cv_show('R',cur_img)

# %%
cur_img=img.copy()
cur_img[:,:,0]=0
cur_img[:,:,2]=0
cv_show('G',cur_img)

# %%
cur_img=img.copy()
cur_img[:,:,1]=0
cur_img[:,:,2]=0
cv_show('B',cur_img)

# %%
img=cv2.resize(img,(500,500))
plt.imshow(img)

# %%
top_size,bottom_size,left_size,right_size=(50,50,50,50)
replicate=cv2.copyMakeBorder(img,top_size,bottom_size,left_size,right_size,borderType=cv2.BORDER_REPLICATE)
plt.imshow(replicate)

# %%
res=cv2.resize(img,(0,0),fx=3,fy=0.5)
plt.imshow(res)

# %%
img2=cv2.imread(r"D:\picture\p1.jpg")
img2 = cv2.resize(img2, (img.shape[1], img.shape[0]))
res=cv2.addWeighted(img,0.2,img2,0.8,0)
plt.imshow(res)

# %% [markdown]
# 图像阈值
#
# ret,dst=cv2.threshold(src,thresh,maxval,type)
#
# src:输入图（单通道）
#
# thresh:阈值
#
# maxval:图像超过阈值所赋予的值
#
# type:二值化操作类型

# %%
img_gray=cv2.imread(r"D:\picture\p2.jpg",cv2.IMREAD_GRAYSCALE)
ret,thresh1=cv2.threshold(img_gray,127,255,cv2.THRESH_BINARY)
ret,thresh2=cv2.threshold(img_gray,127,255,cv2.THRESH_BINARY_INV)
ret,thresh3=cv2.threshold(img_gray,127,255,cv2.THRESH_TRUNC)
ret,thresh4=cv2.threshold(img_gray,127,255,cv2.THRESH_TOZERO)
ret,thresh5=cv2.threshold(img_gray,127,255,cv2.THRESH_TOZERO_INV)

titles=['Original Image','BINARY','BINARY_INV','TRUNC','TOZERO','TOZERO_INV']
images=[img_gray,thresh1,thresh2,thresh3,thresh4,thresh5]

for i in range(6):
    plt.subplot(2,3,i+1),plt.imshow(images[i],'gray') # 将画布分割成网格状区域，每个区域绘制独立的图表，适用于对比展示多组数据
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()

# %% [markdown]
# 均值滤波
# 简单的平均卷积操作

# %%
blur=cv2.blur(img,(3,3))
cv_show('blur',blur)

# %% [markdown]
# 方框滤波
# 基本和均值一样,可以选择归一化
#
# box=cv2.boxFilter(img,-1,(3,3),normalize=False)
#
# cv_show('box',box)

# %%
box=cv2.boxFilter(img,-1,(3,3),normalize=True)
cv_show('box',box)

# %% [markdown]
# 高斯滤波
#
# 0.6 0.8 0.6
#
# 0.8 1.0 0.8
#
# 0.6 0.8,0.6
#
# 权重近->远:大->小

# %%
aussian=cv2.GaussianBlur(img,(5,5),1)
cv_show('aussian',aussian)

# %% [markdown]
# 中值滤波
# 用中值代替

# %% [markdown]
# 中值滤波
# 用中值代替

# %%
median=cv2.medianBlur(img,5)
cv_show('median',median)

# %%
res=np.hstack((blur,aussian,median))
res=cv2.resize(res,(int(res.shape[1]*0.5),int(res.shape[0]*0.5)))
cv_show('all',res)

# %%
titles=['Original Image','blur','aussian','median']
images=[img,blur,aussian,median]
for i in range(4):
    plt.subplot(1,4,i+1)
    plt.imshow(images[i])
    plt.title(titles[i])
plt.show()

# %% [markdown]
# 形态学-腐蚀操作

# %%
img=cv2.imread(r"D:\picture\erode_input.png")

cv_show('img',img)

# %%
kernel=np.ones((5,5),np.uint8)

erosion=cv2.erode(img,kernel,iterations=1)

cv_show('erosion',erosion)

# %%
kernel=np.ones((2,2),np.uint8)
erosion_1=cv2.erode(img,kernel,iterations=1)
erosion_2=cv2.erode(img,kernel,iterations=2)
erosion_3=cv2.erode(img,kernel,iterations=4)

titles=['Original Image','Erosion_1','Erosion_2','Erosion_3']
images=[img,erosion_1,erosion_2,erosion_3]

for i in range(4):
    plt.subplot(1,4,i+1)
    plt.title(titles[i])
    plt.imshow(images[i])
plt.show()

# %% [markdown]
# 膨胀操作：将腐蚀掉的好的部分还原回去

# %%
img2=erosion_3

kernel=np.ones((2,2),np.uint8)
dilate_1=cv2.dilate(img2,kernel,iterations=1)
dilate_2=cv2.dilate(img2,kernel,iterations=2)
dilate_3=cv2.dilate(img2,kernel,iterations=3)

titles=['Original Image','Dilate_1','Dilate_2','Dilate_3']
images=[img2,dilate_1,dilate_2,dilate_3]

for i in range(4):
    plt.subplot(1,4,i+1)
    plt.title(titles[i])
    plt.imshow(images[i])
plt.show()

# %% [markdown]
# 开运算：先腐蚀，再膨胀

# %%
img=cv2.imread(r"D:\picture\erode_input.png")

kernel=np.ones((5,5),np.uint8)
opening=cv2.morphologyEx(img,cv2.MORPH_OPEN,kernel)

res1=np.hstack((img,opening))

cv_show('opening',res1)

# %% [markdown]
# 闭运算：先膨胀，再腐蚀（主要用来填充内部空洞，连接断裂区域）

# %%
kernel=np.ones((5,5),np.uint8)
closing=cv2.morphologyEx(img,cv2.MORPH_CLOSE,kernel)

res2=np.hstack((img,closing))

cv_show('closing',res2)

# %%
res=np.vstack((res1,res2))
plt.imshow(res)

# %% [markdown]
# 梯度运算
# 梯度=膨胀-腐蚀

# %%
kernel=np.ones((5,5),np.uint8)
gradient=cv2.morphologyEx(img,cv2.MORPH_GRADIENT,kernel)
cv_show('gradient',gradient)

# %% [markdown]
# 礼帽=原始输入-开运算结果

# %%
tophat=cv2.morphologyEx(img,cv2.MORPH_TOPHAT,kernel)
cv_show('tophat',tophat)

# %% [markdown]
# 黑帽=闭运算=闭运算结果-原始输入

# %%
blackhat=cv2.morphologyEx(img,cv2.MORPH_BLACKHAT,kernel)
cv_show('blackhat',blackhat)

# %%
img=cv2.imread(r"D:\picture\p2.jpg",cv2.IMREAD_GRAYSCALE)
img=cv2.resize(img,(int(img.shape[1]*0.5),int(img.shape[0]*0.5)))
cv_show('img',img)

# %% [markdown]
# dst=cv2.Sobel(src,ddepth,dx,dy,ksize)
#
# ddepth:图像深度
#
# dx,dy分别表示水平和竖直方向
#
# ksize是Soble算子的大小

# %%
sobelx=cv2.Sobel(img,cv2.CV_64F,1,0,ksize=3)
cv_show('sobelx',sobelx)

# %%
sobelx=cv2.convertScaleAbs(sobelx)
cv_show('sobelx',sobelx)

# %%
sobely=cv2.Sobel(img,cv2.CV_64F,0,1,ksize=3)
sobely=cv2.convertScaleAbs(sobely)
cv_show('sobely',sobely)

# %%
sobelxy=cv2.addWeighted(sobelx,0.5,sobely,0.5,0)
cv_show('sobelxy',sobelxy)

# %%
# 不建议直接计算

wrong=cv2.Sobel(img,cv2.CV_64F,1,1,ksize=3)
wrong=cv2.convertScaleAbs(wrong)
cv_show('wrong',wrong)

# %%
sobels=[sobelxy,wrong]
res=np.hstack(sobels)
plt.imshow(res)

# %%
scharrx=cv2.Scharr(img,cv2.CV_64F,1,0)
scharry=cv2.Scharr(img,cv2.CV_64F,0,1)
scharrx=cv2.convertScaleAbs(scharrx)
scharry=cv2.convertScaleAbs(scharry)
scharrxy=cv2.addWeighted(scharrx,0.5,scharry,0.5,0)

laplacian=cv2.Laplacian(img,cv2.CV_64F)
laplacian=cv2.convertScaleAbs(laplacian)

res=np.hstack((sobelxy,scharrxy,laplacian))
plt.imshow(res)

# %% [markdown]
# Canny边缘检测
#
# 1.使用高斯滤波器，以平滑图像，消除噪声
#
# 2.计算图像中每个像素点的梯度强度和方向
#
# 3.应用非极大值抑制(NMS)，以消除边缘检测带来的杂散效应
#
# 4.应用双阈值检测来确定真实和潜在的边缘
#
# 5.通过抑制孤立的弱边缘最终完成边缘检测

# %%
v1=cv2.Canny(img,80,150)
v2=cv2.Canny(img,80,100)

res=np.hstack((v1,v2))
plt.imshow(res)

# %% [markdown]
# cv2.findContours(img,mode,method)
#
#
# mode:轮廓检索模式:
#
# -RETR_EXTERNAL:只检索最外面的轮廓
#
# -RETR_LIST:检索所有的轮廓，并将其保存到一条链表当中
#
# -RETR_CCOMP:检索所有的轮廓，并将他们组织为两层，顶层是各部分的外部边界，第二层是空洞的边界
#
# -RETR_TREE:检索所有的轮廓，并重构嵌套轮廓的整个层次
#
#
# method:轮廓逼近方法
#
# -CHAIN_APPROX_NONE:以Freeman链码的方式输出轮廓，所有其它方法输出多边形
#
# -CHAIN_APPROX_SIMPLE:压缩水平的，垂直的和斜的部分，也就是函数只保留他们的终点部分
#
# 为了提高准确率，使用二值图像

# %%
ret,thresh=cv2.threshold(img,127,255,cv2.THRESH_BINARY)
cv_show('thresh',thresh)

# %%
contours,hierarchy=cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_NONE)

# %%
img_contours=cv2.imread(r"D:\picture\p2.jpg")
img_contours=cv2.resize(img_contours,(int(img_contours.shape[1]*0.5),int(img_contours.shape[0]*0.5)))
cv2.drawContours(img_contours, contours, -1, (0, 0, 255), 2)
cv_show('img_contours',img_contours)

# %% [markdown]
# 高斯金字塔：向下采样方法(缩小)
#
# 1.将Gi与高斯内核卷积
#
# 2.将所有偶数行和列去除
#
# 高斯金字塔：向上采样方法(放大)
#
# 1.将图像在每个方向扩大为原来的两倍，新增行和列用0填充
#
# 2.使用先前同样的内核乘以4与放大后的图像卷积，获得近似值

# %%
up=cv2.pyrUp(cv2.resize(img,(int(img.shape[1]*0.5),int(img.shape[0]*0.5))))
cv_show('up',up)

# %%
down=cv2.pyrDown(img)
cv_show('down',down)

# %% [markdown]
# 拉普拉斯金字塔

# %%
down_up=cv2.pyrUp(down)
l_l=img-down_up
cv_show('l_l',l_l)

# %% [markdown]
# cv2.calcHist(images,channels,mask,histSize,ranges)
#
# -images:原图像格式为uint8或float32
#
# -channels:[B][G][R]
#
# -mask:掩模图像
#
# -histSize:BIN的数目
#
# -ranges:像素值范围通常为[0,256]

# %%
img=cv2.imread(r"D:\picture\p2.jpg",cv2.IMREAD_GRAYSCALE)
hist=cv2.calcHist([img],[0],None,[256],[0,256])
plt.hist(img.ravel(),256)
plt.show()

# %%
img=cv2.imread(r"D:\picture\p2.jpg")
for i,col in enumerate(('b','g','r')):
    histr=cv2.calcHist([img],[i],None,[256],[0,256])
    plt.plot(histr,color=col)
    plt.xlim([0,256])

# %% [markdown]
# mask操作

# %%
# 创建mask
img=cv2.imread(r"D:\picture\p2.jpg",0)
img=cv2.resize(img,(int(img.shape[1]*0.5),int(img.shape[0]*0.5)))
mask=np.zeros(img.shape[:2],np.uint8)
print(mask.shape)
mask[100:300,100:400]=255
cv_show('mask',mask)
# Out:
# (768, 512)

# %%
cv_show('img',img)

# %%
masked_img=cv2.bitwise_and(img,img,mask=mask)
cv_show('masked_img',masked_img)

# %%
hist_full=cv2.calcHist([img],[0],None,[256],[0,256])
hist_mask=cv2.calcHist([img],[0],mask,[256],[0,256])

# %%
plt.subplot(221),plt.imshow(img,'gray')
plt.subplot(222),plt.imshow(mask,'gray')
plt.subplot(223),plt.imshow(masked_img,'gray')
plt.subplot(224),plt.plot(hist_full),plt.plot(hist_mask)
plt.xlim([0,256])
plt.show()

# %% [markdown]
# 直方图均衡化

# %%
plt.hist(img.ravel(),256)
plt.show()

# %%
equ=cv2.equalizeHist(img)
plt.hist(equ.ravel(),256)
plt.show()

# %%
res=np.hstack((img,equ))
cv_show('res',res)

# %% [markdown]
# 自适应直方图均衡化

# %%
clahe=cv2.createCLAHE(clipLimit=2.0,tileGridSize=(8,8))

# %%
clahe_img = clahe.apply(img) 
cv_show('clahe_img',clahe_img)

# %% [markdown]
# 傅里叶变换

# %% [markdown]
# 傅里叶变换的作用：
#
# -高频：变化剧烈的灰度分量，例如边界
#
# -低频：变化缓慢的灰度分量，例如一片大海

# %% [markdown]
# 滤波
#
# -低通滤波器：只保留低频，会使得图像模糊
#
# -高通滤波器：只保留高频，会使得图像细节增强

# %%
img_float32=np.float32(img)
dft=cv2.dft(img_float32,flags=cv2.DFT_COMPLEX_OUTPUT)
dft_shift=np.fft.fftshift(dft)
# 得到灰度图能表示的形式
magnitude_spectrum=20*np.log(cv2.magnitude(dft_shift[:,:,0],dft_shift[:,:,1]))
plt.subplot(121),plt.imshow(img,cmap='gray')
plt.title('Input Image'),plt.xticks([]),plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum,cmap='gray')
plt.title('Magnitude Spectrum'),plt.xticks([]),plt.yticks([])
plt.show()

# %%
rows,cols=img.shape
crow,ccol=int(rows/2),int(cols/2)

# 低通滤波
mask=np.zeros((rows,cols,2),np.uint8)
mask[crow-30:crow+30,ccol-30:ccol+30]=1

# IDFT
fshift=dft_shift*mask
f_ishift=np.fft.ifftshift(fshift)
img_back=cv2.idft(f_ishift)
img_back=cv2.magnitude(img_back[:,:,0],img_back[:,:,1])

plt.subplot(121),plt.imshow(img,cmap='gray')
plt.title('Input Image'),plt.xticks([]),plt.yticks([])
plt.subplot(122),plt.imshow(img_back,cmap='gray')
plt.title('Result'),plt.xticks([]),plt.yticks([])
# Out:
# (Text(0.5, 1.0, 'Result'), ([], []), ([], []))

# %%
# 高通滤波
mask=np.ones((rows,cols,2),np.uint8)
mask[crow-30:crow+30,ccol-30:ccol+30]=0

# IDFT
fshift=dft_shift*mask
f_ishift=np.fft.ifftshift(fshift)
img_back=cv2.idft(f_ishift)
img_back=cv2.magnitude(img_back[:,:,0],img_back[:,:,1])

plt.subplot(121),plt.imshow(img,cmap='gray')
plt.title('Input Image'),plt.xticks([]),plt.yticks([])
plt.subplot(122),plt.imshow(img_back,cmap='gray')
plt.title('Result'),plt.xticks([]),plt.yticks([])
# Out:
# (Text(0.5, 1.0, 'Result'), ([], []), ([], []))
